# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import curve_fit
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("/content/china_gdp.csv")

# %%
data.describe()
# Out:
#              Year         Value
# count    55.00000  5.500000e+01
# mean   1987.00000  1.437042e+12
# std      16.02082  2.500085e+12
# min    1960.00000  4.668518e+10
# 25%    1973.50000  1.395123e+11
# 50%    1987.00000  3.074796e+11
# 75%    2000.50000  1.268748e+12
# max    2014.00000  1.035483e+13

# %%
data.head()
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10

# %%
X = data['Year'].values
y = data['Value'].values

# %%
def exp_model(x, a, b):
    return a * np.exp(b*x)

# %%
plt.plot(X, y, color='blue')

# %%
guess = [0.001109,0.01826]
n = len(data['Year'])
y_pre = np.empty(n)
for i in range (n):
  y_pre[i]= exp_model(X[i], guess[0], guess[1])
  #print(y_pre[i])
plt.plot(X, y, color='blue')
plt.plot(X, y_pre, color='red')

# %%
c,cov= curve_fit(exp_model,X,y,guess,maxfev=1000000000)
print (c)
# Out:
# [1.05750979e-123 1.55504824e-001]

# %%
for i in range (n):
  y_pre[i]= pow_model(X[i], c[0], c[1])
  #print(y_pre[i])
plt.plot(X, y, color='blue')
plt.plot(X, y_pre, color='red')
